# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.cluster import KMeans

# %%
import pandas as pd
df = pd.read_csv("../data/processed/nepal_features.csv")

# %%
import numpy as np

# %%
cluster_features = df[['age','BMI','lifestyle_risk_score','ses_risk_score']]
X_scaled = StandardScaler().fit_transform(cluster_features)

# %%
X_scaled_df = pd.DataFrame(X_scaled, columns=cluster_features.columns)

# %%
X_scaled_df.head()
# Out:
#         age       BMI  lifestyle_risk_score  ses_risk_score
# 0 -1.636188 -0.095347              0.100504       -0.383893
# 1  0.853363  0.358687              2.613098       -0.383893
# 2  0.438437 -1.457451             -1.155793        0.745204
# 3 -0.391413 -1.457451             -1.155793       -1.512990
# 4 -0.391413 -1.457451             -1.155793       -1.512990

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
df['segment_id'] = kmeans.fit_predict(X_scaled)
# Out:
# C:\Users\bipul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
df.head()
# Out:
#    person_id  age  gender  province  urban_rural education_level wealth_index  \
# 0          1   22    Male         6            1         Primary       Medium
# 1          2   58    Male         2            1          Higher          Low
# 2          3   52    Male         7            0             NaN          Low
# 3          4   40    Male         3            1          Higher       Medium
# 4          5   40  Female         4            1       Secondary         High
#
#    smoker  alcohol_use  physical_activity  BMI  systolic_bp  diastolic_bp  \
# 0       1            0                  1   26          157            60
# 1       1            1                  0   28          108            72
# 2       0            0                  1   20          105            80
# 3       0            0                  1   20          156            96
# 4       0            0                  1   20          133            89
#
#    diabetes_flag  hypertension_flag BMI_category  lifestyle_risk_score  \
# 0              0                  1   Overweight                     1
# 1              1                  0   Overweight                     3
# 2              0                  0       Normal                     0
# 3              0                  1       Normal                     0
# 4              0                  0       Normal                     0
#
#    ses_risk_score  segment_id
# 0               1           1
# 1               1           0
# 2               2           0
# 3               0           2
# 4               0           2

# %%
segment_profile = df.groupby('segment_id').agg({
    'age':'mean', 'BMI':'mean', 
    'lifestyle_risk_score':'mean', 
    'ses_risk_score':'mean', 
    'person_id':'count'
}).rename(columns={'person_id':'population'})

# %%
segment_profile.head()
# Out:
#                   age        BMI  lifestyle_risk_score  ses_risk_score  \
# segment_id
# 0           54.888889  24.055556              1.444444        2.055556
# 1           31.000000  29.294118              0.764706        1.294118
# 2           51.200000  26.000000              0.466667        0.533333
#
#             population
# segment_id
# 0                   18
# 1                   17
# 2                   15

# %%
def label_segment(row):
    if row['age'] < 35 and row['lifestyle_risk_score'] < 1:
        return "Young Healthy Low Risk"
    elif 35 <= row['age'] < 55:
        return "Middle Age Emerging Risk"
    else:
        return "Elderly High Risk"

# %%
segment_profile['segment_name'] = segment_profile.apply(label_segment, axis=1)

# %%
segment_profile.head()
# Out:
#                   age        BMI  lifestyle_risk_score  ses_risk_score  \
# segment_id
# 0           54.888889  24.055556              1.444444        2.055556
# 1           31.000000  29.294118              0.764706        1.294118
# 2           51.200000  26.000000              0.466667        0.533333
#
#             population              segment_name
# segment_id
# 0                   18  Middle Age Emerging Risk
# 1                   17    Young Healthy Low Risk
# 2                   15  Middle Age Emerging Risk

# %%
segment_map = segment_profile['segment_name'].to_dict()

# %%
df['segment_name'] = df['segment_id'].map(segment_map)

# %%
df.head()
# Out:
#    person_id  age  gender  province  urban_rural education_level wealth_index  \
# 0          1   22    Male         6            1         Primary       Medium
# 1          2   58    Male         2            1          Higher          Low
# 2          3   52    Male         7            0             NaN          Low
# 3          4   40    Male         3            1          Higher       Medium
# 4          5   40  Female         4            1       Secondary         High
#
#    smoker  alcohol_use  physical_activity  BMI  systolic_bp  diastolic_bp  \
# 0       1            0                  1   26          157            60
# 1       1            1                  0   28          108            72
# 2       0            0                  1   20          105            80
# 3       0            0                  1   20          156            96
# 4       0            0                  1   20          133            89
#
#    diabetes_flag  hypertension_flag BMI_category  lifestyle_risk_score  \
# 0              0                  1   Overweight                     1
# 1              1                  0   Overweight                     3
# 2              0                  0       Normal                     0
# 3              0                  1       Normal                     0
# 4              0                  0       Normal                     0
#
#    ses_risk_score  segment_id              segment_name
# 0               1           1    Young Healthy Low Risk
# 1               1           0  Middle Age Emerging Risk
# 2               2           0  Middle Age Emerging Risk
# 3               0           2  Middle Age Emerging Risk
# 4               0           2  Middle Age Emerging Risk

# %%
df.to_csv("../data/processed/nepal_segmented.csv", index=False)
segment_profile.to_csv("../data/processed/nepal_segment_profile.csv")

# %%
df
# Out:
#     person_id  age  gender  province  urban_rural education_level  \
# 0           1   22    Male         6            1         Primary
# 1           2   58    Male         2            1          Higher
# 2           3   52    Male         7            0             NaN
# 3           4   40    Male         3            1          Higher
# 4           5   40  Female         4            1       Secondary
# 5           6   62  Female         5            1             NaN
# 6           7   22  Female         1            0         Primary
# 7           8   54    Male         4            0       Secondary
# 8           9   28    Male         4            0         Primary
# 9          10   22    Male         6            1             NaN
# 10         11   45    Male         7            0       Secondary
# 11         12   68    Male         5            0       Secondary
# 12         13   56    Male         3            0             NaN
# 13         14   57    Male         3            0         Primary
# 14         15   55  Female         3            0             NaN
# 15         16   58    Male         6            1       Secondary
# 16         17   44  Female         3            1       Secondary
# 17         18   24  Female         2            1       Secondary
# 18         19   61    Male         3            0          Higher
# 19         20   41  Female         1            1          Higher
# 20         21   44  Female         1            0         Primary
# 21         22   37    Male         1            1             NaN
# 22         23   27    Male         6            0       Secondary
# 23         24   66  Female         6            0          Higher
# 24         25   58    Male         5            0          Higher
# 25         26   51    Male         4            0             NaN
# 26         27   38    Male         6            0             NaN
# 27         28   60  Female         2            0             NaN
# 28         29   46  Female         7            0             NaN
# 29         30   41  Female         4            0       Secondary
# 30         31   41  Female         7            0       Secondary
# 31         32   29    Male         2            1         Primary
# 32         33   22  Female         4            0         Primary
# 33         34   46    Male         5            0          Higher
# 34         35   64    Male         4            0         Primary
# 35         36   21  Female         4            0          Higher
# 36         37   62    Male         2            1          Higher
# 37         38   61  Female         3            0         Primary
# 38         39   32  Female         2            1             NaN
# 39         40   50  Female         3            0          Higher
# 40         41   26  Female         5            0       Secondary
# 41         42   57  Female         5            0         Primary
# 42         43   54    Male         5            1       Secondary
# 43         44   36    Male         3            0       Secondary
# 44         45   21    Male         7            0          Higher
# 45         46   68    Male         1            0         Primary
# 46         47   41    Male         3            0          Higher
# 47         48   64  Female         1            0          Higher
# 48         49   53    Male         3            0             NaN
# 49         50   58    Male         7            0             NaN
#
#    wealth_index  smoker  alcohol_use  physical_activity  BMI  systolic_bp  \
# 0        Medium       1            0                  1   26          157
# 1           Low       1            1                  0   28          108
# 2           Low       0            0                  1   20          105
# 3        Medium       0            0                  1   20          156
# 4          High       0            0                  1   20          133
# 5          High       0            1                  1   27          126
# 6           Low       0            1                  0   18          144
# 7          High       0            0                  1   27          122
# 8           Low       0            0                  0   26          107
# 9          High       0            0                  0   25          143
# 10         High       0            0                  1   29          110
# 11         High       0            1                  1   26          133
# 12          Low       0            0                  0   30          156
# 13         High       1            0                  0   30          156
# 14          Low       0            1                  0   33          121
# 15       Medium       0            0                  0   31          146
# 16       Medium       0            0                  0   26          136
# 17          Low       0            0                  1   26          128
# 18          Low       1            0                  0   22          108
# 19         High       0            0                  1   28          122
# 20       Medium       0            0                  1   20          139
# 21       Medium       0            0                  1   33          159
# 22       Medium       0            0                  0   32          100
# 23       Medium       1            0                  1   20          143
# 24         High       0            0                  1   31          150
# 25          Low       1            0                  1   19          157
# 26         High       0            0                  1   30          125
# 27         High       0            0                  1   19          107
# 28       Medium       0            1                  1   26          116
# 29          Low       0            1                  0   29          151
# 30          Low       0            0                  1   30          152
# 31         High       0            0                  0   25          138
# 32         High       1            0                  1   33          107
# 33          Low       0            0                  1   31          107
# 34          Low       1            0                  0   21          128
# 35          Low       1            0                  1   29          135
# 36          Low       0            0                  0   30          101
# 37         High       1            0                  1   23          141
# 38         High       0            0                  0   30          132
# 39          Low       0            0                  1   33          100
# 40         High       1            1                  0   31          105
# 41          Low       1            0                  1   30          127
# 42       Medium       0            1                  1   28          143
# 43       Medium       0            0                  1   22          149
# 44         High       0            1                  1   31          125
# 45         High       1            1                  1   24          117
# 46          Low       0            1                  1   27          158
# 47          Low       0            1                  0   23          127
# 48          Low       0            1                  1   23          118
# 49          Low       0            0                  0   20          126
#
#     diastolic_bp  diabetes_flag  hypertension_flag BMI_category  \
# 0             60              0                  1   Overweight
# 1             72              1                  0   Overweight
# 2             80              0                  0       Normal
# 3             96              0                  1       Normal
# 4             89              0                  0       Normal
# 5             91              0                  0   Overweight
# 6             81              0                  1  Underweight
# 7             64              0                  0   Overweight
# 8             75              0                  0   Overweight
# 9             99              0                  1   Overweight
# 10            61              1                  0   Overweight
# 11            95              0                  0   Overweight
# 12            87              1                  1        Obese
# 13            71              1                  1        Obese
# 14            91              1                  0        Obese
# 15            93              1                  1        Obese
# 16            61              0                  0   Overweight
# 17            64              0                  0   Overweight
# 18            86              0                  0       Normal
# 19            99              1                  0   Overweight
# 20            60              0                  0       Normal
# 21            86              0                  1        Obese
# 22            65              0                  0        Obese
# 23            86              0                  1       Normal
# 24            84              1                  1        Obese
# 25            63              0                  1       Normal
# 26            87              0                  0        Obese
# 27            95              0                  0       Normal
# 28            94              0                  0   Overweight
# 29            61              1                  1   Overweight
# 30            69              1                  1        Obese
# 31            69              0                  0   Overweight
# 32            78              0                  0        Obese
# 33            65              1                  0        Obese
# 34            94              0                  0       Normal
# 35            91              0                  0   Overweight
# 36            92              1                  0        Obese
# 37            67              0                  1       Normal
# 38            60              0                  0        Obese
# 39            96              1                  0        Obese
# 40            71              0                  0        Obese
# 41            86              1                  0        Obese
# 42            96              1                  1   Overweight
# 43            61              0                  1       Normal
# 44            60              0                  0        Obese
# 45            60              0                  0       Normal
# 46            66              0                  1   Overweight
# 47            62              0                  0       Normal
# 48            92              0                  0       Normal
# 49            84              0                  0       Normal
#
#     lifestyle_risk_score  ses_risk_score  segment_id              segment_name
# 0                      1               1           1    Young Healthy Low Risk
# 1                      3               1           0  Middle Age Emerging Risk
# 2                      0               2           0  Middle Age Emerging Risk
# 3                      0               0           2  Middle Age Emerging Risk
# 4                      0               0           2  Middle Age Emerging Risk
# 5                      1               0           2  Middle Age Emerging Risk
# 6                      2               3           0  Middle Age Emerging Risk
# 7                      0               1           2  Middle Age Emerging Risk
# 8                      1               3           1    Young Healthy Low Risk
# 9                      1               0           1    Young Healthy Low Risk
# 10                     0               1           2  Middle Age Emerging Risk
# 11                     1               1           2  Middle Age Emerging Risk
# 12                     1               2           0  Middle Age Emerging Risk
# 13                     2               2           0  Middle Age Emerging Risk
# 14                     2               2           0  Middle Age Emerging Risk
# 15                     1               0           2  Middle Age Emerging Risk
# 16                     1               0           2  Middle Age Emerging Risk
# 17                     0               1           1    Young Healthy Low Risk
# 18                     2               2           0  Middle Age Emerging Risk
# 19                     0               0           2  Middle Age Emerging Risk
# 20                     0               2           0  Middle Age Emerging Risk
# 21                     0               0           1    Young Healthy Low Risk
# 22                     1               1           1    Young Healthy Low Risk
# 23                     1               1           0  Middle Age Emerging Risk
# 24                     0               1           2  Middle Age Emerging Risk
# 25                     1               2           0  Middle Age Emerging Risk
# 26                     0               1           1    Young Healthy Low Risk
# 27                     0               1           2  Middle Age Emerging Risk
# 28                     1               1           2  Middle Age Emerging Risk
# 29                     2               2           0  Middle Age Emerging Risk
# 30                     0               2           1    Young Healthy Low Risk
# 31                     1               1           1    Young Healthy Low Risk
# 32                     1               2           1    Young Healthy Low Risk
# 33                     0               2           1    Young Healthy Low Risk
# 34                     2               3           0  Middle Age Emerging Risk
# 35                     1               2           1    Young Healthy Low Risk
# 36                     1               1           2  Middle Age Emerging Risk
# 37                     1               2           0  Middle Age Emerging Risk
# 38                     1               0           1    Young Healthy Low Risk
# 39                     0               2           1    Young Healthy Low Risk
# 40                     3               1           1    Young Healthy Low Risk
# 41                     1               3           0  Middle Age Emerging Risk
# 42                     1               0           2  Middle Age Emerging Risk
# 43                     0               1           2  Middle Age Emerging Risk
# 44                     1               1           1    Young Healthy Low Risk
# 45                     2               2           0  Middle Age Emerging Risk
# 46                     1               2           1    Young Healthy Low Risk
# 47                     2               2           0  Middle Age Emerging Risk
# 48                     1               2           0  Middle Age Emerging Risk
# 49                     1               2           0  Middle Age Emerging Risk
